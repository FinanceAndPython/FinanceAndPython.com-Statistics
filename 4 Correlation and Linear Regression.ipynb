# %%
import numpy as np
import matplotlib.pyplot as plt
scores1 = [400+np.random.normal()*100 for _ in range(100)]
scores2 = [600+np.random.normal()*70 for _ in range(100)]

# %%
totalScores = [scores1,scores2]
plt.boxplot(totalScores)
plt.show()

# %%
from random import randint
xVals = list(range(100))
yVals = [x+randint(-5, 5) for x in xVals]

# %%
plt.scatter(xVals,yVals)
plt.show()

# %%
from random import randint
xVals = list(range(100))
yVals = [x+randint(-20, 20) for x in xVals]
plt.scatter(xVals,yVals)
plt.show()

# %%
from random import randint
xVals = list(range(100))
yVals = [100-x+randint(-20, 20) for x in xVals]
plt.scatter(xVals,yVals)
plt.show()

# %%
from random import randint
xVals = list(range(100))
yVals = [x**2 for x in xVals]
plt.scatter(xVals,yVals)
plt.show()

# %%
xVals = list(range(100))
yVals = [x+randint(-10,10) for x in xVals]
plt.scatter(xVals,yVals)
plt.show()
print(np.corrcoef(xVals,yVals))
# Out:
# [[ 1.          0.98112074]
#  [ 0.98112074  1.        ]]

# %%
print(np.corrcoef(xVals,yVals)[0][1])
# Out:
# 0.981120739141

# %%
xVals = list(range(100))
yVals = [x for x in xVals]
plt.scatter(xVals,yVals)
plt.show()
print(np.corrcoef(xVals,yVals)[0][1])
# Out:
# 1.0

# %%
xVals = list(range(100))
yVals = [x*2 for x in xVals]
plt.scatter(xVals,yVals)
plt.show()
print(np.corrcoef(xVals,yVals)[0][1])
# Out:
# 1.0

# %%
xVals = list(range(100))
yVals = [x**2 for x in xVals]
plt.scatter(xVals,yVals)
plt.show()
print(np.corrcoef(xVals,yVals)[0][1])
# Out:
# 0.967644392713

# %%
xVals = list(range(100))
yVals = [x**2 for x in xVals]
yVals2 = [y**.5 for y in yVals]
plt.scatter(xVals,yVals2)
plt.show()
print(np.corrcoef(xVals,yVals2)[0][1])
# Out:
# 1.0

# %%
xVals = list(range(100))
yVals = [x+randint(-25,25) for x in xVals]
plt.scatter(xVals,yVals)
plt.show()
print(np.corrcoef(xVals,yVals)[0][1])
# Out:
# 0.897468766084

# %%
xVals = list(range(100))
yVals = [randint(-25,25) for x in xVals]
plt.scatter(xVals,yVals)
plt.show()
print(np.corrcoef(xVals,yVals)[0][1])
#Notice that there is a chance that we actually find a correlation when there isn't because it's random
# Out:
# -0.0450071392716

# %%
for _ in range(20):
    xVals = list(range(100))
    yVals = [randint(-25,25) for x in xVals]
    print(np.corrcoef(xVals,yVals)[0][1])
# Out:
# -0.0820172302662
# -0.10771020748
# -0.0702333593678
# 0.0284505728589
# 0.0577829820234
# -0.161707588644
# 0.0335147780473
# 0.0983448823511
# -0.0952319417429
# -0.0163430898056
# -0.0800033627926
# -0.00686164005748
# 0.000190836553614
# -0.005825579497
# -0.044504207306
# -0.0717706893603
# -0.202770328883
# 0.0531652917613
# 0.0228380836797
# -0.0367141739765

# %%
for _ in range(20):
    xVals = list(range(100000))
    yVals = [randint(-25,25) for x in xVals]
    print(np.corrcoef(xVals,yVals)[0][1])
# Out:
# -0.00181998295791
# -0.00251132086659
# -0.000102638532159
# -0.000312015707227
# 0.000256758187337
# -0.000733658524319
# -0.00134019228252
# -0.00168161029026
# 0.0045353343089
# 0.000527679069943
# -0.000252576655517
# 0.00276446992475
# 0.00209957367641
# 0.000892811033539
# 8.29380660748e-05
# -0.00635330294044
# -0.00165851226839
# 0.0036168087885
# -0.00117639741655
# -0.00159926220447

# %%
xVals = list(range(100))
yVals = [x+randint(-20,20) for x in xVals]
result = scipy.stats.linregress(xVals,yVals)
print(result)
# Out:
# LinregressResult(slope=1.0903270327032704, intercept=-3.4611881188118829, rvalue=0.93728723833250527, pvalue=1.1904059730463704e-46, stderr=0.040958685465577314)

# %%
print(result.slope)
print(result.intercept)
# Out:
# 1.0903270327
# -3.46118811881

# %%
print(result.rvalue)
print(result.pvalue)
# Out:
# 0.937287238333
# 1.19040597305e-46

# %%
m = result.slope
b = result.intercept
fittedValues = [m*x+b for x in xVals]
print(fittedValues)
# Out:
# [-3.4611881188118829, -2.3708610861086123, -1.2805340534053422, -0.19020702070207207, 0.90012001200119851, 1.9904470447044691, 3.0807740774077388, 4.1711011101110094, 5.26142814281428, 6.3517551755175496, 7.4420822082208211, 8.5324092409240908, 9.6227362736273605, 10.713063306330632, 11.803390339033902, 12.893717371737171, 13.984044404440443, 15.074371437143714, 16.164698469846982, 17.255025502550254, 18.345352535253525, 19.435679567956793, 20.526006600660065, 21.616333633363336, 22.706660666066604, 23.796987698769875, 24.887314731473147, 25.977641764176418, 27.067968796879686, 28.158295829582958, 29.248622862286226, 30.338949894989497, 31.429276927692769, 32.51960396039604, 33.609930993099312, 34.700258025802583, 35.790585058505847, 36.880912091209119, 37.97123912391239, 39.061566156615662, 40.151893189318933, 41.242220222022205, 42.332547254725469, 43.422874287428741, 44.513201320132012, 45.603528352835283, 46.693855385538555, 47.784182418241826, 48.874509450945091, 49.964836483648362, 51.055163516351634, 52.145490549054905, 53.235817581758177, 54.326144614461448, 55.41647164716472, 56.506798679867984, 57.597125712571255, 58.687452745274527, 59.777779777977798, 60.868106810681063, 61.958433843384334, 63.048760876087606, 64.139087908790884, 65.229414941494156, 66.319741974197427, 67.410069006900699, 68.50039603960397, 69.590723072307242, 70.681050105010513, 71.771377137713785, 72.861704170417056, 73.952031203120299, 75.042358235823571, 76.132685268526842, 77.223012301230114, 78.313339333933385, 79.403666366636656, 80.493993399339928, 81.584320432043199, 82.674647464746471, 83.764974497449742, 84.855301530153014, 85.945628562856285, 87.035955595559557, 88.126282628262828, 89.2166096609661, 90.306936693669371, 91.397263726372643, 92.487590759075914, 93.577917791779186, 94.668244824482457, 95.758571857185729, 96.848898889889, 97.939225922592271, 99.029552955295543, 100.11987998799881, 101.21020702070206, 102.30053405340533, 103.3908610861086, 104.48118811881187]

# %%
plt.scatter(xVals,yVals)
plt.plot(xVals,fittedValues,"r")
plt.show()

# %%
yVals = np.array(yVals)
fittedValues = np.array(fittedValues)
residuals = yVals-fittedValues
print(residuals)
plt.scatter(xVals,residuals)
plt.show()
# Out:
# [ -1.55388119e+01   1.93708611e+01   1.28053405e+00   1.41902070e+01
#    1.30998800e+01   9.55295530e-03  -1.20807741e+01  -1.61711011e+01
#    2.73857186e+00   1.64824482e+00   4.55791779e+00   2.46759076e+00
#   -1.56227363e+01  -1.27130633e+01   2.19660966e+00  -1.18937174e+01
#    1.50159556e+01  -9.07437144e+00  -6.16469847e+00   1.77449745e+01
#   -2.34535254e+00   6.56432043e+00   2.47399340e+00   3.38366637e+00
#   -7.70666067e+00   1.42030123e+01   1.51126853e+01  -1.09776418e+01
#   -7.06796880e+00  -3.15829583e+00   2.75137714e+00   1.86610501e+01
#    5.70723072e-01  -1.25196040e+01  -1.96099310e+01  -1.47002580e+01
#   -1.79058506e+00  -1.78809121e+01   6.02876088e+00  -1.80615662e+01
#    1.84810681e+00   1.27577798e+01   6.67452745e-01   1.15771257e+01
#   -1.45132013e+01  -5.60352835e+00  -1.66938554e+01   5.21581758e+00
#   -9.87450945e+00   1.70351635e+01  -1.30551635e+01   1.18545095e+01
#   -1.23581758e+00   1.16738554e+01   1.15835284e+01  -8.50679868e+00
#    1.54028743e+01   1.63125473e+01   2.22222022e+00   1.31318932e+01
#    1.60415662e+01   1.59512391e+01   5.86091209e+00   9.77058506e+00
#   -3.31974197e+00   3.58993099e+00  -2.05003960e+01   1.04092769e+01
#   -5.68105011e+00   2.22862286e+00  -1.08617042e+01  -1.19520312e+01
#   -1.00423582e+01  -1.61326853e+01   1.67769877e+01  -1.53133393e+01
#    1.15963336e+01  -4.93993399e-01  -5.84320432e-01   1.63253525e+01
#   -2.17649745e+01  -1.98553015e+01   1.20543714e+01   9.96404440e+00
#    1.87371737e+00  -2.21660966e+00   1.36930633e+01  -2.39726373e+00
#    6.51240924e+00  -1.57791779e+00  -2.36682448e+01   1.22414281e+01
#    1.41511011e+01   1.00607741e+01  -1.60295530e+01  -1.41198800e+01
#   -7.21020702e+00  -1.23005341e+01   5.60913891e+00   1.05188119e+01]

# %%
xVals = list(range(100))
yVals = [x**2 for x in xVals]

result = scipy.stats.linregress(xVals,yVals)
m = result.slope
b = result.intercept
fittedValues = [m*x+b for x in xVals]

plt.scatter(xVals,yVals)
plt.plot(xVals,fittedValues,"r")
plt.title("Regression")
plt.show()
yVals = np.array(yVals)
fittedValues = np.array(fittedValues)
residuals = yVals-fittedValues
plt.scatter(xVals,residuals)
plt.title("Residuals")
plt.show()

# %%
xVals = list(range(100))
yVals = [x+randint(-5, 5)*x/5for x in xVals]

result = scipy.stats.linregress(xVals,yVals)
m = result.slope
b = result.intercept
fittedValues = [m*x+b for x in xVals]

plt.scatter(xVals,yVals)
plt.plot(xVals,fittedValues,"r")
plt.title("Regression")
plt.show()
yVals = np.array(yVals)
fittedValues = np.array(fittedValues)
residuals = yVals-fittedValues
plt.scatter(xVals,residuals)
plt.title("Residuals")
plt.show()
